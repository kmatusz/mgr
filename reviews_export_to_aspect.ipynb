# %%
import pandas as pd
import numpy as np


# %%
df_full = pd.read_csv('data/reviews_with_en.csv').drop('Unnamed: 0', axis = 1)

df = df_full[['message_en']].dropna()
df
# Out:
# /root/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                                message_en
# 3                 I received it well before the deadline.
# 4       Congratulations lannister stores loved shoppin...
# 9       efficient device. on the website the brand of ...
# 12        But a little, braking ... for the value ta Boa.
# 15      Reliable seller, ok product and delivery befor...
# ...                                                   ...
# 99985   Entregou dentro do prazo. O produto chegou em ...
# 99992   O produto não foi enviado com NF, não existe v...
# 99998   Excelente mochila, entrega super rápida. Super...
# 100000  Solicitei a compra de uma capa de retrovisor c...
# 100001  meu produto chegou e ja tenho que devolver, po...
#
# [41751 rows x 1 columns]

# %%
with open('data/message_reviews_to_aspect.txt', 'w') as f:
    f.write("\n".join(list(df.message_en)))

# %%
list(df.message_en)
# Out:
# ['I received it well before the deadline.',
#  'Congratulations lannister stores loved shopping online safe and practical Congratulations to all happy Easter',
#  'efficient device. on the website the brand of the device is printed as 3desinfector and when it arrives with another name ... update with the correct brand since it is the same device',
#  'But a little, braking ... for the value ta Boa.',
#  'Reliable seller, ok product and delivery before the deadline.',
#  'I WOULD LIKE TO KNOW WHAT HAS BEEN, I ALWAYS RECEIVED AND THIS PURCHASE NOW HAS DISCUSSED',
#  'Terrible',
#  'Store note 10',
#  'thank you for your kind attention',
#  'The purchase was made easily. The delivery was made well before the given deadline. The product has already started to be used and to date, without problems.',
#  'very beautiful and cheap watch.',
#  'Did not like ! I bought a pig in a poke',
#  'I always buy over the Internet and delivery takes place before the agreed deadline, which I believe is the maximum period. At stark, the maximum term has expired and I have not yet received the product.',
#  'I got exactly what I expected. Other orders from other sellers were delayed, but this one arrived on time.',
#  'I recommend ,',
#  'very good',
#  'I&#39;m completely in love, super responsible and reliable store!',
#  'Nothing to get my order.',
#  'Very good. very fragrant.',
#  'great seller arrived before the deadline, I loved the product',
#  'Smooth and efficient purchasing process.',
#  'I hope it lasts because it is made of fur.',
#  'I received only 1 Midea Split STYLE control. Missed Remote Control for Air Conditioning Consul',
#  'good',
#  'Very beautiful',
#  'Everything happened as contracted and the delivery was made before the deadline I am satisfied',
#  'I loved it, beautiful, very delicate',
#  'Great store for partnership: very fast, well packaged and quality products! Only the cost of shipping that was a little sour.',
#  'I recommend the seller ...',
#  'The product did not arrive within the stipulated time and caused inconvenience, because I scheduled my son&#39;s vacation trip, based on the deadline. I live in Bahia and he in Cuiabá alone. Now, the house is empty.',
#  'Product delivered as requested, and very soon. Congratulations!',
#  'I bought two units and only received one and now what do I do?',
#  'Good product, but what came to me does not match the photo in the ad.',
#  'Very inferior product, badly finished.',
#  'The canine patrol backpack kit is beautiful !! My grandchild will love it !! Thanks!!',
#  'Wonderful',
#  'On-time delivery',
#  'Fulfilled what was promised in the purchase and with a satisfactory delivery time',
#  'I asked for a refund and no response so far',
#  'Super fast.',
#  'Pleased',
#  'congratulations station ... always arrives with a lot of antecedence .. Thank you very much ....',
#  'OK I RECOMMEND',
#  'Product arrived, but my PC was unable to recognize the USB ports.',
#  'Very good quality product, arrived before the promised deadline',
#  'This was the order Bucket With 128 Pieces - Assembling Blocks 2 units - R $ 25.00 each (NOT DELIVERED) Sold and delivered targaryen Eva Rug Nº Letters 36 Pieces Children 1 unit - R $ 35.90 (THIS WAS DELIVERED)',
#  'Very fast delivery Congratulations',
#  'I bought three packs of five sheets each of transfer paper for dark tissue and received only two',
#  'Only one product was missing, I received it today, thank you very much! All right! Att Elenice.',
#  'The thermal bag besides being beautiful is super spacious. Product as advertised and super fast delivery, delivered well before the deadline.',
#  'It took too long for delivery',
#  'super fast delivery .... arrived before the date ...',
#  'The delivery was split in two. There was no statement from the store. I came to think that they had only shipped part of the product.',
#  'Does not work does not sync',
#  'Recommend to all customers',
#  'Liked it',
#  'GREAT',
#  'I really liked the bath game. The flower print, the embroidery, everything was very beautiful. Great product.',
#  'Only one piece arrived, but the note and guarantee contain the two jewels.',
#  'I DID NOT RECEIVE THE PRODUCT AND IS IN THE SYSTEM I RECEIVED BEYOND PAYING EXPENSIVE SHIPPING',
#  'I bought the watch, unisex and sent a women&#39;s watch, much smaller than the specifications of the ad.',
#  'I always shop at lannister. For me it&#39;s the best online store',
#  'Excellent quality product',
#  'Great value for money',
#  'OK',
#  'I liked the attention with the delivery',
#  'If it were glass, it would have broken; it came in the box with no protection inside, the box was very dented. Sorry .. but I like to buy from you.',
#  'The play did not fit',
#  'I bought the product on the 25th of February and today the 29th of March it had not been delivered to my residence. I don&#39;t know if the post office in Brazil is terrible or it was the store itself that took a long time to post.',
#  'I made my purchase 30 days ago and haven&#39;t received my product yet. Need to improve deliveries',
#  'I hope to receive this week, which would not be so extravagant, however ... more delay than that would make me give up baratheon.',
#  'Delivered on time, I was happy with the purchase I made',
#  'Beautiful watch I loved it',
#  'I bought two pendant chandeliers, with the targaryen partner and only one chandelier was sent to me. I filed a complaint, but I still haven&#39;t received a response. I await solution from Lojas lannister.',
#  'Very good high quality!',
#  'Beautiful product, delivered well worth and on time. I recommend!',
#  'Very good',
#  '1 product was missing and the ones I received 1 came broken',
#  'arrived on time and the product is of excellent quality! No more back pain, I&#39;m sleeping very well!',
#  'here it is describing as delivered only that until now I have not received',
#  'I think tracking the product should be better and more accurate, but overall it was a great experience',
#  'I haven&#39;t had the opportunity to test it yet',
#  'I started using now',
#  'nothing to declare',
#  'Buy a correct product on the cover but internal be another. ???????',
#  'Super fast delivery',
#  'I placed an order for 4 bottles of olive oil. 2 arrived in one day and the other 2 almost 48 hours later. Contact with the store is very difficult, both via email and by phone. The suspense is over but I don’t buy anymore',
#  'The product arrived very fast and of good quality I recommend the product',
#  'I can not! I am waiting for the arrival of the product I bought! As soon as that happens, I will have my opinion formed!',
#  'I bought two products and received only one. I sent two emails to the store and got no feedback. I am dissatisfied.',
#  'I would not recommend this store nor do I intend to buy again. The merchandise was delivered after the deadline and almost 1 month after purchase. On the lannister website they usually arrive before the deadline. I was very strange',
#  'I recommend',
#  'It met my expectation.',
#  'Delivery ahead of time. Very practical and easy to handle product.',
#  'disappointed',
#  'great product not only came manual, but without problems.',
#  'One of the pieces did not fit, it was of a different diameter. I had to saw and hammer in order to fit and fit. Otherwise, everything is ok.',
#  'Excellent product.',
#  'All right',
#  'Delay in delivery, I hated the service and NEVER buy more. baratheon when selling by themselves was much better!',
#  'Very good product',
#  'my product did not arrive ... according to the screening is stopped in Ribeirão Preto sp ...',
#  'product failed in 1 time of use.',
#  'super recommend professional quality product',
#  'so far I haven&#39;t received the product.',
#  'The store advertises one product and delivers another.',
#  'very good and fast when i saw it had already arrived',
#  'The product arrived very well',
#  'great',
#  'Despite being delivered quickly, they replaced the METEORO box with the BORNE box. When I tried to complain on lannister the system was down. The guitar and accessories were correct.',
#  'Very satisfied',
#  'congratulations to store and dealer although it took a while',
#  'Delivered on time, with good validity period.',
#  'The set of towels is beautiful more beautiful than in the photo, I loved it.',
#  'product was delivered with one of the handles with problems (1 fixing pin is missing)',
#  '02/14 was scheduled for delivery of the order and the tracking marked that the product had already been delivered on the date but in reality was not delivered. The product was only delivered on 02/28.',
#  'SHOP BEYOND FREIGHT TO BE VERY EXPENSIVE. THE PRODUCT TAKES ALMOST 30 BUSINESS DAYS, TO ARRIVE AT YOUR HOME',
#  'I received it very quickly, but another product came, and not the one I ordered, the model came different, the color, came a cape that has no zipper, anyway, I don&#39;t recommend it.',
#  'I always bought at Stark and I am satisfied.',
#  'I made the purchase by table and thanks to God everything worked out I am very grateful you can trust.',
#  'They canceled my purchase the day before delivery, I called lannister and the attendants didn&#39;t know what was going on, a mess, now I&#39;m waiting to see if they&#39;ll be charged',
#  'quality product and efficient delivery. I received it long before the arrangement. I recommend',
#  'Good product came in on time arrived in 08 days are to be congratulated.',
#  'I sent 2 requests through the site to change the address. I got the message that they were going to call me in 48h but they didn&#39;t.',
#  'Everything ok, the baratheon is always responsible with his deliveries.',
#  'the finish that was in the photo was beautiful the one that arrived was an ugly synthetic with an all smudged finish that I didn&#39;t like',
#  'And very cluttered I bought three products but it didn&#39;t come in the backlands it came separately and on a separate date',
#  'A',
#  'fast delivery',
#  'was good',
#  'Right merchandise delivered on time. Thankful',
#  ', too bad !',
#  'The days are past.',
#  'When buying the kit I understood that I would receive 2 bottles of 60 capsules (each) and not 2 bottles with 60 capsules in total. I just won&#39;t return it because I need the product.',
#  'Delivery well before the perfect deadline !!',
#  'Every time I buy more I am satisfied congratulations on honesty with your customers 👏👏👏👏?',
#  'very fast delivery and good to buy with you',
#  'Product do not recommend not reading on any device',
#  'Super fast delivery, congratulations!',
#  'Everything is fast and efficient.',
#  'Wonderful cream and super fast delivery',
#  'Trying to cancel the product since before the invoice was issued. I was not notified that it was in the mail, I had no response to the cancellation and I can&#39;t return it.',
#  'Arrived today without comments',
#  'Good night is unfortunate, this store that I have already made so many purchases and today I am not satisfied even with a watch in the amount of 50.00 reais ... a defective product and so far has not given me back',
#  'Very good! What I expected!',
#  'The protective cover is not exactly what I expected leaves something to be desired in terms of material and quality.',
#  'On the website the product seems to have better quality of material and finish.',
#  'I received my product correctly and within the deadline, checking in the box everything is correct, but not yet assembled. Beautiful product, perfect color, we love it. SUPER RECOMMEND.',
#  'The packaging left something to be desired, the product was almost undamaged, the box was all wrinkled.',
#  'Congratulations .Product delivered well before the deadline. It met my needs.',
#  'I recommend.',
#  'Missed cables and manual',
#  'great arrived well before the deadline.',
#  'Deliver on time very good product.',
#  'The product was only packed with brown paper on the packaging and sent by post. Of course, the packaging arrived crumpled and god knows if the product is working or not, I haven&#39;t tested it yet.',
#  'I think they should send by mail instead of pac',
#  'Last time I buy because today it will be 1 month that I made the purchase and nothing, and if it takes longer to deliver I will be looking for my rights against the lannister and targaryen stores.',
#  'Beautiful ... Just missing instructions for exchanging bracelets.',
#  'Product exactly as described. It arrived well before the deadline!',
#  'The product arrived well before the deadline, I loved the service! Super recommend',
#  'I didn&#39;t like the product, poor quality material.',
#  'Of the two products purchased, only one was delivered!',
#  'I don&#39;t buy more at lannister. Whether you are a lannister partner or not, this targaryen will never use again. When I read that it&#39;s from this company, I run. Absurd. Almost a month to deliver. Extra.com ok',
#  'I received the product correctly',
#  'I received the product within the stated period, I haven&#39;t used it yet.',
#  'The order arrived before the agreed, very good.',
#  'product delivered as advertised.',
#  'receive only 01 piece of product! I need the remaining 2 pieces!',
#  'STORE 10',
#  'The guitar I bought is beautiful, but the color of the sticker does not match the photo of the purchase, but I approved.',
#  'Nor did the invoice',
#  'Arrived before the deadline! Excellent product!',
#  'I work professionally at lannister stores. I indicate for sure',
#  'The MP3 player does not work, even if you change the battery several times. I had to return it.',
#  'super recommend the product which is very good!',
#  'Very good pre workout, one of the best on the market, if not the best.',
#  'The store posted the product and the mail took a while',
#  'I always shop at Stark and I am always well attended, efficient website and great quality products, I recommend everyone to buy with their eyes closed!',
#  'Very good from purchase to delivery td straight and fast',
#  'Everything is OK!',
#  'Targaryen is not to be trusted did not deliver my purchase and placed it in the order tracking that was delivered on 12/14/17 fake company I want to receive my products that were paid with boleto bancari',
#  'Delivery and product quality as expected.',
#  'Excelent, I recommend',
#  'The bag is very beautiful on the outside But inside it has no lining And it is very fragile',
#  'When I installed the ink cartridge, my printer indicated that it was empty, and presented the error message &quot;!&quot; over the ink level marker. I already requested the exchange.',
#  'very good, I recommend the product.',
#  'as for the site I have nothing to question! always super meet the agreed ... always recommend! but the product is weak ..',
#  'good in all aspects',
#  'To this day I am satisfied with sbmarino',
#  'The two leather covers purchased were not delivered. Only one of them. I am waiting for the money back or the delivery of the second cover.',
#  'Liked it!',
#  'I was happy with. The fabric, but I think the top sheet was missing to be complete, I hope they will soon be released.',
#  'Arrived before the deadline is the headboard is beautiful.',
#  'There was some confusion between the seller and the stark, as I received an email from the stark asking for the product to be canceled due to an unforeseen delivery; I denied it and received the product days later.',
#  '10',
#  'I liked the product arrived on time the sellers are to be congratulated',
#  'Excelent reception',
#  'Liked it',
#  'On May 19th I used it and the strap broke without much weight',
#  'Wonderful Brazilian champion&#39;s towel',
#  'The delivery was carried out well ahead of schedule. Good product ... I&#39;m satisfied',
#  'So far so good I&#39;m waiting for the delivery of the product',
#  'The purchase went as expected, from ordering to receiving the product. All right.',
#  'The product was delivered before the deadline.',
#  'I really liked the product, it was exactly the bottle I expected, delivery on time, congratulations, I recommend the store',
#  'I bought the product in black and arrived in red.',
#  'this is the second time I buy in this store, super efficient, fast delivery and before the contracted term, well packaged product, Note 10 Thank you very much',
#  'great',
#  'I thought the backpack was a more resistant material.',
#  'I bought a product and another came. I sent a message informing the error, but I didn&#39;t get a response. Thanks',
#  'the product takes a long time to arrive!',
#  'We only received a watch by mail att',
#  'fast delivery, product as expected',
#  'Everything as advertised .... Great product ...',
#  'Good quality product, exactly as advertised, and the low price is one more attraction.',
#  'Only one unit was delivered, instead of two.',
#  'I loved the product;; I received it before the agreed deadline, it was very beautiful',
#  'Very satisfied.',
#  'Great product but too expensive !!!',
#  'Great products, fast delivery. Super recommend !!!',
#  'yes I received more defective the fittings are two equal and do not close',
#  'I haven&#39;t received it yet',
#  'I had an excellent post sale through Mr. Renato',
#  'I really liked the product, the delivery came before the deadline. I recommend it, it fits well in the cell phone, it does not take away the elegance of the device, like other covers that make it monstrous with its size.',
#  'Very good',
#  'So far I haven&#39;t received it. I bought this device for health reasons, so I don&#39;t recommend this store.',
#  'I recommend it to everyone. Great quality product, delivered without problems.',
#  'Product arrived on time. It came as described and is excellent.',
#  'the product arrived before the deadline, and I really liked it !! now my 3 year old boy will make the most of it !!',
#  'I would like to know when my product will arrive? Since the delivery date has passed, I would like an answer, I am waiting!',
#  'Store Note 10',
#  'Congratulations. I received it before the deadline. everything correct as agreed.',
#  'The delivered product differs from the order it is an inferior product! I would like the problem to be solved! I&#39;m not satisfied with the procedure!',
#  'Really good!',
#  'I bought the product, paid at the boleto and only received half the product, they announced one thing and sent another. Very dissatisfied 😡😡😡',
#  'Delivery before the deadline very well maintained product.',
#  'Great quality product. I loved it!',
#  'Despite the delay in sending the invoice, after it was delivered, delivery was quick and the product came well packaged. I recommend.',
#  'I bought the product on the beginning of March and did not receive it on time, even opening a protocol to resolve my situation',
#  'I did not receive the product, nor any contact from the seller.',
#  'I&#39;m not even able to ratrear :(',
#  'note 10',
#  'Waiting for the installer',
#  'I bought a product to be delivered by that store and I still haven&#39;t received it because the delivery date has passed',
#  'Great service',
#  'Great buy. Great product. I just missed a communication between the purchase and the arrival of the product, just contact. But thanks.',
#  'came as per the order plus the after sales did not answer any of my questions',
#  'I bought two backpacks, I received only one, Christmas is coming and so far nothing!',
#  'Perfect😁',
#  'The price was great, the delivery time is long (more than 1 month to deliver). I bought 2 cartridges and delivered only 1, complained and sent the other still within the delivery period.',
#  'term was extended, but delivered within the term disclosed in the advertisement. Chair as photo, comes to assemble, easier and more beautiful',
#  'Simply gorgeous!! I loved the product!! Perfect size !! I already bought several products, I have been buying at baratheon for years !!',
#  'VERY GOOD! ARRIVED WITHIN THE TERM.',
#  'Great, price, delivered ahead of time and great quality product.',
#  'I bought a Christmas present watch for my son and it hasn&#39;t arrived yet. I sent messages and in the last conversation the watch would arrive yesterday, but I didn&#39;t receive anything.',
#  'could only deliver faster end of year',
#  'Great sale, everything perfect.',
#  'Great quality product !! It arrived before the expected time. Loved &lt;3',
#  'It came well packaged, fast shipping!',
#  'I am very satisfied with my purchase and receipt of the product; within the time limit!',
#  'So far I haven&#39;t received anything, the bedspread was scheduled for the day before yesterday (12/18) and so far nothing',
#  'The brushes came crumpled, not consistent with some photos, but consistent with the description. They are weak, do not fit in the case and a cool shaft',
#  'Product corresponding to my expectations! It was delivered before the deadline!',
#  'I recommend the shop I always buy at lannister.',
#  'The product came different from the one shown in the photo, it is not luxurious, nor quilted as I said.',
#  'It was all normal, as is an internet purchase. Thanks.',
#  'Good bargain.',
#  'Product arrived on time. It is cost-effective, but the bag is not lined and the handle is plastic. I am satisfied.',
#  'I am fully satisfied with my acquisition. And I recommend it. The only thing I don&#39;t agree with is the shipping cost. Very much.',
#  'I bought 02 only sent 01',
#  'it seems that it keeps the food well without wilting (potato straw) but the lid is strange, it seems that it does not close. and the lid&#39;s stainless steel is ugly.',
#  'I am waiting for an answer until today, about my products, they have already been paid for and I have NOT received them yet, they were the same 03 and I need to talk to people and NOT machine or recordings.',
#  'Perfect product and delivery!',
#  'Congratulations 😤 for the excellent quality service.',
#  'Product delivered in advance.',
#  'I liked to buy I received the product before the deadline and of good quality. I recommend.',
#  'Super recommend, stark Always arriving before the planned date = D',
#  'Post office did not deliver',
#  'On-time delivery and product in perfect condition Congratulations to the team',
#  'I have not received the product',
#  'I would like to receive the correct products, I tried to make the exchange by returning the money on the card, but the lannister website does not allow it to be carried out.',
#  'Perfect product, fast delivery. I am delighted. 👏🏽',
#  'my product came defective, i returned as informed.posted in the mail as indicated.and to date i have not received any notification from the company regarding the return and analysis to have my refund',
#  'The order arrived before the deadline. Thanks.',
#  'We only received 1 cartridge, we have already opened a complaint on the website and have not yet received a response.',
#  'High quality product. Description matches the product Delivered on time. I recommend.',
#  'The table top arrived all smashed and beaten.',
#  'On time, however, they could speed up my other product, which was delivered in 2 days.',
#  'The watch is beautiful and the delivery was very fast. I recommend!',
#  'I loved it! Small, easy to use, does not scratch, appeals and cleans the skin .. recommend',
#  'As always, excellent service.',
#  'So far I n receive the product',
#  'As always lannister delivers right',
#  'Perfect product, arrived before the deadline!',
#  'The product was very good, better than expected and delivered on time, I really liked it.',
#  'Very good product and price charged!',
#  'Sdds ',
#  'the product is very good.',
#  'on-time delivery this is important.',
#  'I really liked it, the item came the same as I bought it, I already bought it in other stores and another color came ñ I liked it! With lannister everything is ok.',
#  'The device arrived defective, it is not showing all the functions on the digital display.',
#  'The product is not in the correct measurements indicated in the offer. I will have to call you guys to exchange',
#  'I am waiting for an urgent return.',
#  'Product more than the delivery deadline, I try to solve the problem with the company and I can&#39;t talk to anyone. All they do is pass me on to complain about a system that doesn&#39;t work.',
#  'I only received one product. It is said that I already received both. I didn&#39;t get the shoe rack.',
#  'They gave a very long time for delivery of the product and failed to deliver on time',
#  'Excellent product for anyone.',
#  'everything right delivery on time.',
#  'I did not receive the product.and now?',
#  'It arrived crumpled ...',
#  'I recommend!',
#  'i bought a rubber mat for mitsubishi tr4 the store delivered a horrible pvc mat in the title ta rubber mat tr4, they deceived me and now what to do being that there is an expense for return',
#  'Great perfume. Wonderful fragrance. I recommend',
#  'very good and fast and the product came in good condition now and even do the tests!',
#  'The product exceeded my expectation. The delivery time was brought forward by 7 days. I already installed and it was awesome.',
#  'fast delivery',
#  'Delivery forecast until 10/18, received on 10/05, excellent.',
#  'Plastic curtain, in the photo it looks like woven different design dead colors, a real crap, I don&#39;t recommend anyone buying total disappointment',
#  'I REQUESTED RETURN. DEFECTIVE PRODUCT',
#  'Store itself is good pity the American does not provide customer support',
#  'Exactly what I needed',
#  'I thought the quality of the product was very bad, there was no anchor or screw to fix it to the wall.',
#  'Thank you, it came too fast',
#  'The only problem is that the date stamp is the American stamp.',
#  'I think the product should have a longer shelf life.',
#  'Delivery ahead of time, I recommend this store.',
#  'show ',
#  'Good night the lannister stores are great I love the site today I make very little purchase for abusive shipping unfortunately does not pay as before but we need to buy thanks',
#  'Excellent product, beautiful and sophisticated.',
#  'No invoice came',
#  'thank you very much, because I received the correct product as found on the website, the delivery was super fast. I was very satisfied and I will definitely recommend it to friends.',
#  'Fast product delivery as advertised',
#  'MY PRODUCT HAS NOT BEEN DELIVERED YET, I HAVE ALREADY MADE MY CLAIM AND I HAVE NOT HAD ANY DELIVERY FORECAST. I AM SUPER DISSATISFIED AND I WANT MY MONEY BACK. WAS REPORTING TO PROCON.',
#  'The curtain is not the model I asked for. |',
#  'Printing is coming out with weak ink ...',
#  'I bought Rosa with White Arms and deliver all Black?',
#  'I need a forecast.',
#  'I am very satisfied arrived before the deadline I highly recommend',
#  'Product arrived before the deadline and fully met my expectations.',
#  'On-time delivery, product with no problem',
#  'good',
#  'Good quality and price.',
#  'Always deliver ahead of time.',
#  'very good.super recommend.every delivery right.',
#  'Good people, the lannister attendant was very attentive but the store that should have delivered the product canceled to buy ??? What happened?',
#  'Deliver before the deadline! Perfect product!',
#  'I recommend it to everyone, I had no problem whatsoever, great merchandise and deadline.',
#  'I liked having bought it at this store. Perfect service.',
#  'I bought a chair, received it on time, but the chair came broken at the bottom. They could be more careful in the packaging.',
#  'I always buy and always receive the right product on time or before the deadline',
#  'VERY FAST DELIVERY',
#  'The product was delivered well before the deadline.',
#  'I haven&#39;t installed it yet, I liked it a lot',
#  'Good product. Fast delivery. I recommend',
#  'Product received on time and in perfect condition.',
#  'very good',
#  'I received another doll, I want to return it and I can&#39;t get in touch! I would never buy from that store again!',
#  'great purchase but freight does not pay, weighs in the budget. should have free grates',
#  'N/a',
#  'The product arrived as I imagined, for now I&#39;m enjoying it',
#  'Great fast delivery THANKS',
#  'I think there should be a way to communicate with the company if the order happened not to be delivered',
#  'Good product, good deadline ...',
#  'Very good. It is already the second object I bought and received without any problem',
#  'Beautiful and good quality. I loved it',
#  'The product arrived before the deadline.',
#  'Good night, I didn&#39;t like it because we were never able to talk to you on the phone',
#  'Seller commitment to the customer',
#  'The product did not meet my expectations, because the jars are difficult to open and close and the tray where the jars are going came with rust spots',
#  'Very satisfied super fast delivery .. Show .. congratulations .. I hesitated and bought a cell phone in Bahia houses almost a month ago and they didn’t deliver it ..',
#  'great',
#  'Everything a hundred and on time I recommend',
#  'I did not receive the game in tobacco color. Only red.',
#  'It wasn&#39;t delivered to my house, so I didn&#39;t like it, I don&#39;t have time to go to the post office.',
#  'Perfect purchase.',
#  'The product came spoiled',
#  'My merchandise was not delivered, I already paid the first invoice I want to cancel the purchase because I paid the freight and did not receive the goods.',
#  'PRODUCT ALREADY ARRIVED WITH DEFECT DID NOT FUCK IN ACCORDANCE WITH MY NEED TO USE. UNFORTUNATELY LAST BUY MY TOTALLY DISSATISFIED.',
#  'I received only 1 box with 100 units, and ordered 2 boxes.',
#  'I am extremely disappointed. This had never happened',
#  'I BUY TWO PENDANTS ONLY ONE ARRIVED. DO I NEED TO KNOW WHAT WAS THERE?',
#  'I recommend this store delivery straight',
#  'Everything complies and very fast delivery !!!! Too bad I didn&#39;t check the color, because it was black and needed gray. Another point that I had to sand a little to work, but nothing too much.',
#  'Fast and correct delivery',
#  'Product easy to assemble and perfectly serves the purpose to optimize space.',
#  'Product came with dents and is also not working properly.',
#  'I like the product',
#  'Great quality product',
#  'I&#39;ve been waiting for more than twenty days and I still haven&#39;t received my product and I can&#39;t get any information.',
#  'I am waiting for the company&#39;s position to return the product.',
#  'The zip code was misspelled, I had to pick up the product at the post office in the neighboring city.',
#  'supplier did not ship the correct product. I ordered the chocolate flavor and was sent another flavor.',
#  'I recommend this store.',
#  'Great product.',
#  'Excellent',
#  'So continue with this responsibility to the consumer, both in the product and in the delivery period. First time I buy and I will buy many. Thanks.',
#  'I loved it. Modern, beautiful, my coffee corner will be top',
#  'well, it was what I expected.',
#  'Everything went as agreed, nothing to complain about.',
#  'Easy to handle, even the present meets expectations.',
#  'Gorgeous watch delivers ahead of schedule',
#  'It came as the most beautiful simple advertised.',
#  'Product matches the ad',
#  'The product has not arrived yet',
#  'satisfied I recommend',
#  'I loved it, it came quickly, I&#39;m still going to test it. Thank you !!',
#  'I really enjoyed what I bought with you guys thank you very soon I&#39;ll do other shopping vanda',
#  'I have not received the product...',
#  'I received it, the scholarship is different but I liked it, it was scheduled for January 31, I was finding it a long time because it is for school and I am waiting for the purchase voucher of the first purchase of the scholarship that didn&#39;t work',
#  'I received the product I wanted and before the agreed deadline, very good, I recommend it for sure.',
#  'In the advertisement it says Electric mixer and a laptop came, I have three that broke so I wanted an electric one, you should specify the products better',
#  'Product delivered before the agreed deadline. It is not the first time that I buy through the Lojas lannister website and I recommend this company for its seriousness in dealing with customers.',
#  'I bought 2 products so they sent me 1 and gave me no justification!',
#  'Thank you very good.',
#  '*******************',
#  'On schedule',
#  'I received it before the estimated deadline.',
#  'I just thought the doll was bigger. More is cool',
#  'I had a problem with delivery, as there was no one at home to receive the goods at the time they passed.',
#  'Attentive, call to follow up. Good shelf life. It took a while to arrive. Now it&#39;s time to check the quality of the product.',
#  'Very efficient delivered very fast I recommend',
#  'Very beautiful the Clock!',
#  'Great product and on-time delivery',
#  'It arrived before the deadline, but some of the product leaked!',
#  'Whenever I buy with you my items arrive in perfect condition ....',
#  'Product delivered before the deadline in great condition.',
#  'Very good.',
#  'Super fast delivery. Great quality product. I recommend.',
#  'Hello only problem was that we did not receive the product at the requested address, we had to go after the product at the post office in the city center, and we paid even more to receive it at home.',
#  'Gorgeous product, great',
#  'Excellent',
#  'I expected more, the towels could be thicker.',
#  'Delivery one day ahead of schedule',
#  'It takes a while to heat up, even at full power 5. But it works well. In the first days of use it has a smell like burning rubber, but it passes ... I recommend it for its practicality and cost / benefit.',
#  'It was delivered well packaged. Fast delivery as promised. Comform the image.',
#  'Everything happened efficiently',
#  'The product arrived before the deadline and in perfect condition.',
#  'The order was not delivered to my address, I paid up front and had to go to the distribution center to pick up my order. Lack of respect to pay to receive at home and not receive.',
#  'The product does not match what I bought, the film is much smaller than the cell phone screen and does not cover the entire screen.',
#  'product as advertised, and came before the deadline ... perfect',
#  'Good product and delivered ahead of schedule.',
#  'I haven&#39;t used it on any trips yet, but it looks very good.',
#  'The product was sent to the destination city on 03/31 and so far I have not received it.',
#  'I recommend',
#  'The product was not delivered!',
#  'I just didn&#39;t receive my product and I don&#39;t have a decent positioning of what will happen.',
#  'I did not receive the shower arm with diverter, only the 20x20 shower with a 30cm arm.',
#  'I love shopping at lannister stores',
#  'Very fast delivery, and excellent product',
#  'Great',
#  'The product may be malfunctioning. Or my phone is unable to read.',
#  'Product delivered',
#  'Shameless shop. They did not deliver the order and they had the impudence that I canceled it. Crap seller. stark chose his mistress very badly.',
#  'Very good',
#  'I received the product that is fake I want my money back',
#  'PRODUCT DID NOT COME AS IT WAS ON THE SITE. SHOWED SITE CALENDAR BUT WHEN I RECEIVED IT CAME WITHOUT AND THIS DIFFICULT TO MAKE THE EXCHANGE AND RETURN OF THE PRODUCT',
#  'Good product. Delivery ahead of time',
#  'Good',
#  'really enjoyed',
#  'I bought two products, one of which did not arrive. An audio adapter cable.',
#  'I really liked it, everything arrived right before the delivery deadline.',
#  'Product delivered on time.',
#  'Targaryen supplier sent me a massager completely different from the one I bought, of lower price and full of negative reviews. Nobody makes mistakes by sending a superior right, curious ... That is, n recommend',
#  'I received the product on time, everything ok',
#  'Too bad, one product didn&#39;t come and the other came wrong ..',
#  'I OPEN A RETURN PROTOCOL, A PRODUCT OF LOW QUALITY HAS PROBLEMED ON THE FIRST DAY OF USE. lannister HAS TURNED A FREE MARKET .... 6 ORDERS 6 PROBLEMS',
#  'On-time delivery and as described on the website',
#  'My request for number 03-492551892 came in parts. a Manchester Polo Match was missing. That each day shows that it is in one place and I enter the site, it appears that it has already been delivered!',
#  'A lannister always if overcoming',
#  'I was surprised by the effectiveness. Great attention.',
#  'great service, all right, delivered on time.',
#  'Thank you for the quality of the product, and for the tbm delivery that was scheduled for 08/10 and arrived on 07/22. I loved it. Congratulations.',
#  'The goods have not been delivered yet ..',
#  'I haven&#39;t used the product yet',
#  'I received the order in a normal way and on time, however, I received an estimated delivery date first and later, the date was increasing. I didn&#39;t like that attitude. It took 2 weeks.',
#  'I asked for it to be canceled before the nf was issued because I had received an equal gift ... they did not cancel ... they sent it like this ... I asked when the nf had not yet been issued',
#  'Very beautiful gave a charm in my room.',
#  'Great service and delivery before the deadline.',
#  'I did not receive the complete product, I bought quantity 02 and received only 01. and it appears in the delivery note has quantity 02 and volume 01. I want to receive the other at no cost. Because the mistake was not me',
#  'I recommend.',
#  'The bags are beautiful on the outside, the color is very close to the photo, but inside there is no description lining and the finish left a little to be desired, plus the delivery was super fast',
#  'urgent need of this merchandise, the maximum deadline was until the 3rd and so far has not arrived',
#  'Great spacious and resistant material material I liked it!',
#  'Great service',
#  'Providing high quality services',
#  'The product is of very low quality',
#  'Product delivered well packaged, in perfect condition.',
#  'It took but delivered!',
#  'The purchase made were two praying bears, one pink and one blue, I received only one of the products I purchased, the pink one, I am waiting for a return from the seller, about what happened and if I will receive the other one',
#  'Defective product presents risk because it is not reliable, I have already avoided e-mail and made calls and without return.',
#  'In general, it is satisfactory because it is laser engraved. But precisely because it is laser, it leaves something to be desired regarding the centralization of the pendant with the brand, as well as the quality of the engraving.',
#  'Arrived before the scheduled date, I would recommend the stark store to my friends to be congratulated.',
#  'Beautiful carpet. It arrived long before the deadline.',
#  'Really enjoyed',
#  'I could have streamlined the delivery! But I received the product in great condition!',
#  'I received 1 board. But the other is missing because they are 2. The order is missing 02-645381563',
#  'Protudo arrived in great condition, and before the deadline!',
#  'Product of excellent quality and the delivery was made ahead of schedule. Very satisfied.',
#  'The product is very beautiful and has an excellent price! The delivery was super fast, taking place well before the deadline! I recommend! The room was awesome !!!!',
#  'The product came without invoice, I had to order by phone.',
#  'The product is not good.',
#  'Very satisfied I recommend',
#  'Can buy without fear',
#  'I like to buy in this store because agent ñ need to notify delivery',
#  'Excellent product!!',
#  'Product delivered within 10 days',
#  'the product description was wrong and I was unable to use the product, I asked for the cancellation 15 days ago and I still have no answer',
#  'Very good, excellent',
#  'effective service and on-time delivery',
#  'It arrived just before the deadline, that&#39;s good',
#  'I really liked the pillow. It is as described on the website.',
#  'Super recommend. Delivery and products ok.',
#  'No punctuality, no customer satisfaction.',
#  'Satisfied with the acquisition and business. Delivery on time, with well packaged product, with the invoice, original box, warranty and user manual. First impressions the watch is in perfect shape.',
#  'Met expectations',
#  'VERY GOOD, ORDER ARRIVED RIGHT',
#  'my mosquito net came with two holes on the top and ask for a King mosquito net but not Kiung but QUEEM',
#  'Very good',
#  'Product arrived quickly and as advertised.',
#  'Low quality product.',
#  'Quality product, fair price, on-time delivery. The product met my expectations. Recommend the seller.',
#  'I was sent the wrong product!',
#  'I purchased and paid for two units and received only one unit. Awaiting negotiation.',
#  'I loved the product, it arrived before the stipulated deadline. I am very satisfied.',
#  'everything is OK',
#  'The painting was delivered by post and arrived with a broken back wood and the damaged canvas of the painting sunk ... that is ... the product arrived damaged',
#  'Imported product, mine came defective',
#  'Simple and beautiful product',
#  'I really enjoyed the agility in delivery',
#  'I haven&#39;t received it yet',
#  'Expected a little bigger',
#  'the product is reasonable! product shipping proper packaging! arrived crumpled almost damaged it!',
#  'Product arrived before the deadline, very well packed by the supplier, without damage. The quality product is very good.',
#  'I would just like to know the correct delivery day.',
#  'Very good products!',
#  'Great product',
#  'Good morning ... I bought a red metallic drinker ... and I got a pink drinker ... obs ... my dog is male ...',
#  'It was not delivered, the first time this happens.',
#  'the product took a month to deliver. too much time could have arrived before the deadline. that&#39;s all ok.',
#  'I bought 2 units of the product, it came out damaged since the packaging is very weak, and it came with two holes in the bottom of the pan, due to the pressure that dog placed on top of it.',
#  'I just think I could have bought more cartridges, but I didn&#39;t do them because each cartridge came with a different freight, something that could be placed in a single package, which would make shipping cheaper.',
#  'I bought it in the lannister, because it is a trustworthy store, but when the product arrived I found that what was sold by the Targus brand was actually a counterfeit product,',
#  'Excellent service',
#  'Order was canceled and the store still shipped the product. I returned the product and want the refund of the purchase on my credit card.',
#  'I PURCHASED A POT SET WITH 8 POTS AND A RED PRESSURE POT AND OVAL TYPES. I RECEIVED A SET WITH 6 POTS AND A SET OF BLACK SPATULAS. THING I DID NOT ASK. JUST A FRYING PAN CAME.',
#  'I bought it one day and received it the next and the merchandise is excellent !!!',
#  'I didn&#39;t like the quality of the padding',
#  'As I have already requested, I need to make the return. It was not delivered on time. I have already requested here and I have already contacted the seller. I&#39;m waiting to make the return.',
#  'LIKED THE FAST DELIVERY',
#  'I want to know the other products were 3 items',
#  'Congratulations',
#  'I can&#39;t give an opinion about the product because I didn&#39;t receive it, about the store I don&#39;t recommend it, because it delays deliveries.',
#  'Product arrived on time, in perfect condition and came packed in an incredible way. Very well packaged ... Arrived without any scratches!',
#  'I didn&#39;t receive the product',
#  'I bought 2 (two) identical products and had to pay 2 (two) freight. The Company could have put it in a single package and charge only one freight. Product delivered in perfect condition. Great product.',
#  'Great product!',
#  'Quality product, very long delivery',
#  'Very fast delivery and product in great condition.',
#  'I wonder if the product has changed packaging. Because I bought the red packaging and received another packaging all flowery. I need to know if it&#39;s the same product.',
#  'Beautiful toilet and the description, came with a very small stain, but nothing that is a problem, I recommend.',
#  'product delivered totally different from the one purchased',
#  'Great at TDS aspects',
#  'I&#39;m still waiting',
#  'Aida did not receive the product',
#  'I received it before the promised date. I recommend this store.',
#  'It took almost thirty days .Too long',
#  'It depends so that I can evaluate if they solve my problem after the purchase was 4 the post office will only deliver a package containing 2 pens',
#  'Really enjoyed',
#  'Good',
#  'Good afternoon! I had problems with my order yes! The wrong musketeer came. I asked for a Queen size, to be dragged to the floor and with the circle on top quite large. Small came from nor double bed',
#  'so far everything perfect, product and delivery on time',
#  'I bought 2 watches, but only 1 was delivered',
#  'ok product, received on time, well ahead of schedule.',
#  'Delivery was anticipated, plus one of the pressure cookers came with the broken support.',
#  'Everything is OK.',
#  'Great product! I recommend!',
#  'DELIVERY VERY LONG, I PURCHASED ON 03/26/2018 AND UNTIL I HAVE NOT RECEIVED THE PRODUCTS',
#  'good',
#  'The product arrived as advertised. Liked it.',
#  'Within the deadline and information of the product forwarding clearly',
#  'Great. I recommend.',
#  'The product then came Wrong',
#  'I DID NOT RECEIVE THE PRODUCT, THE PRODUCT IS CONSENT AS SHIPPED TO THE MAIL OF RIBEIRÃO PRETO. THE MAIL DID NOT RECEIVE THE PRODUCT. SEND VARIOUS MESSAGE TO targaryen AND DID NOT GET. THIS targaryen IS DIRTYING HIS NAME',
#  'Liked it',
#  'The product came out of specification. The cap sold had the Citroën symbol, but the cap came without this symbol.',
#  'So I liked it but it’s not all that I didn’t think would be better',
#  'Trusted shop arrived in praso',
#  'loved the product, super easy to handle and lannister is CONGRATULATED, as it arrived WELL BEFORE the deadline.',
#  'Super recommend the products are beautiful !! 😍😍',
#  'I ordered two wallets. One came defective and the other came wrong, ñ that&#39;s where I asked for .... I asked for a refund and I believe it will go well.',
#  'Great engine, just don&#39;t come the racks together!',
#  'I really liked the product. Very fast delivery.',
#  'Excellent product and delivery arrived ahead of schedule !!! Great',
#  'product arrived before the set deadline.',
#  'Excellent arrived before the agreement, congratulations!',
#  'I really liked the product, it has no burning eyes and no smell smoothed 90% of my hair but I think the second time it would be super smooth.',
#  'Delivered before the stipulated deadline. GREAT. That&#39;s why I always buy on the site.',
#  'IN spite of not having a good finish, the product is well functional.',
#  'Perfect delivery, even before the deadline. product in perfect condition and of excellent quality.',
#  'aaa',
#  'Great product',
#  'It came right and super fast! I loved my chandelier !!!!',
#  'Beautiful, good and arrived fast',
#  'I received only 1 metal detector and the purchase was 2 units. How can we solve this? I await guidance.',
#  'Good night on purchase says wireless 150mbs Multilaser plus 3g would not have come the 3g modem that connects to the USB on it.',
#  'Pleased',
#  'It arrived on time. Very beautiful. Thanks.',
#  'Very good, I recommend',
#  'optimi product delivery excellent',
#  'cool. all right. fast delivery',
#  'I bought two pairs of rings and only two male units arrived at my house! I am waiting for a response from the company to send the other two female units other than cheopu!',
#  'I think they should change the mode of delivery, as the Post Office leaves much to be desired. They came once to deliver my product and it was a Sunday afternoon and they sent the product back to the sender.',
#  'I THINK YOU SHOULD FURNISH US FASTER WHERE THIS PRODUCT IS',
#  'Loved it....',
#  'I received from this store only two pending. I paid the ticket in advance and a product did not come: It is a Medium Brushed Half Ball Aluminum Pendant in the amount of R $ 90. I want $ back.',
#  'You are leaving something to be desired I bought products with you and you delay delivery and still cancel the order without authorization',
#  'Product delivered before the deadline. Good cost-benefit.',
#  'I didn&#39;t receive another order from that store. I&#39;m waiting for them to send me the two 2kg proteins ...',
#  'In addition to ñ comply with what was promised in the case of delivery, the store still gives the wrong explanation, informed that the address is wrong',
#  'The product was delivered before the deadline. And approved!',
#  'I made a purchase of two but both have the same code and only one came, I bought a bedspread that arrived just right but the skirt of the bed didn&#39;t come',
# ...
#  'Great quality product, congratulations.',
#  'very good the store',
#  'delivered before the deadline, product monitoring system gives credibility to the store.',
#  'Good afternoon my product came missing parts and the time I buy at lannister stores always came right and this time no',
#  'arrived before the deadline',
#  'It&#39;s taking too long',
#  'Unfortunately the product came defective, the media is corrupted .... I lost the exchange because I made the packaging unusable without first testing it, which makes me unable to exchange it ...',
#  'I loved the product. Arrived before the deadline',
#  'I always buy at baratheon and I love everything.',
#  'Always meets the delivery deadlines',
#  'everything happened as predicted',
#  'Perfect product fast delivery',
#  'THEFT! There are 2 units on the invoice but only ONE comes in the package. Do you want to charge without delivering?',
#  'DID NOT SEND MY ORDER',
#  'Excellent product for collectors. I recommend!',
#  'Original product, fast delivery and good price !!!',
#  'Good product and delivery in excellent fast time',
#  'Loved the product is excellent purchase!',
#  'VERY GOOD VACUUM CLEANER, LIGHT AND EASY TO HANDLE!',
#  'Good product material, but does not fit perfectly.',
#  'It pays to buy. For those who want a reserve material to use in training, it is worth a lot.',
#  'It came straight and fast good quality!',
#  'Gorgeous product and great quality',
#  'Quality product, I recommend ...',
#  'Product delivered on time',
#  'The product is very good I recommend It is fast',
#  'Order: 02-662119905 Double Handle X-double Legitimate Leather Cameras Dslr Double Strap INFORMATION THAT THE PRODUCT WASN&#39;T DELIVERED, BUT ON THE SITE IT IS BEING INFORMED THAT IT WAS. I ASK FOR CLARIFICATIONS.',
#  'I recommend !',
#  'A women&#39;s watch came in place of the men&#39;s watch that I ordered, I canceled and refunded what I received and also about the chargeback and received no response.',
#  'Very good',
#  'Either the film is wrong or the model does not protect the entire front',
#  'Satisfactory!',
#  'Excellent.',
#  'I love to shop with lannister stores. They are reliable.',
#  'I bought the cover in black, but I received it on 07/23/2018 in white, I would like to exchange it, since the product came in the wrong color.',
#  'I didn&#39;t receive the product on the scheduled date, I sent several messages for information, since the tracking was stopped for 3 weeks, I just didn&#39;t like it and I don&#39;t recommend delivery from targaryen',
#  'Product arrived well ahead of schedule',
#  'I really liked the product!',
#  'I am very satisfied',
#  'I bought 2 units of the wallpaper. But only 1 roll arrived. How to resolve this situation m',
#  'Super recommend the store. Product delivered long before the deadline and of excellent quality.',
#  'Very good. Early delivery makes the difference;',
#  'Excellent store ... fast shipping and right product.',
#  'Everything is correct except for the delay, which is not the fault of the supplier but of the Post Office.',
#  'Good product, fast delivery',
#  'Optimal quality and well packaged',
#  'I recommend everyone to buy products at lannister, my purchase was delivered satisfactorily and on time.',
#  'On the lannister website the delivery date would be 1/4, but in the tracking code the product was posted in the mail on 1/4, that is, the product is still in transit today 1/6.',
#  'Delivery made well before the deadline, arrived well packaged and excellent product !!',
#  'Perfect beautiful product, arrived on time all right',
#  'Great product, delivery ahead of time. I recommend!',
#  'The product arrived ahead of schedule',
#  'Quick yet came with a toast! top',
#  'I want my product',
#  'Purchase operating system that is easy to handle and understand. Fast delivery and the meter purchased corresponds with the advertisement. Would buy again.',
#  'The product arrived torn',
#  'The product is made of a good quality material, but it is very difficult to place the blade accurately in the knife and may even be injured when inserting or removing the blade!',
#  'Good product, I liked it. It just needed to be a little more elevated. but I recommend it.',
#  'Easy to wash and compact. My wife loved it.',
#  'They delivered the products, but they did not meet the delivery deadline.',
#  'The product is great and original I recommend.',
#  'My purchase came in half, I bought a cell phone case and a glass film just came the case the film didn&#39;t come',
#  'Reason q one of the headphones I can&#39;t tune to FM radio in black n the rest looks good.',
#  'arrived quickly !!!!',
#  'Delay, product not delivered!',
#  'The product arrived on time and in perfect condition!',
#  'Excellent product to play on PS2. It is said that it also works for PS3 and PC, I will test it.',
#  'Good product.',
#  'Product arrived on time without any details.',
#  'Great quality material!',
#  'Get in super fast!',
#  'delivered well packaged',
#  'Excellent',
#  'Two days after the deadline, one month after the purchase and nothing of the product arrives !! Expensive and inefficient freight !!',
#  'Everything as agreed.',
#  'I received the product with open box, unsealed, without invoice, without purchase order and with a different sender than the announcement. I want money back. Discontent',
#  'I recommend it, it&#39;s a good watch, but I had to disable the second half, and in the manual I had to explain why the TR function is used, other than that I recommend, it was delivered well before the deadline',
#  'Great quality product.',
#  'The delivery was carried out correctly, within the agreed. The product came out perfect and in working condition.',
#  'A quantity of the product has been delivered. Since I ordered two quantities',
#  'I am satisfied with the product.',
#  'Great seller, great product arrived on time I recommend',
#  'The delivery time could be shorter!',
#  'blinded before the deadline, VERY GOOD !!!!',
#  'Very good! I really liked it! Great Fabric! Met My Expectations! 👏👏👏 Super Recommend! 👍',
#  'Product suited to my needs',
#  'I recommend',
#  'Trusted store',
#  'Excellent quality product, responsible sellers, on-time delivery ... Super satisfied.',
#  'First time I shop online and I don&#39;t regret it. It arrived on time.',
#  'I received a brush from another brand. I can&#39;t solve the problem. Bad service from lannister and partner stores !!!',
#  'everything arrived, I recommend it.',
#  'Great',
#  'I loved it',
#  'Great store',
#  'It arrived very fast and looks good, I will only find out with the use, the cover for the 3-seater sofa came a little smaller, the width came 1.46, but the 2-seater came in the right size.',
#  'I loved the product, it arrived before the deadline',
#  'Images at the time of purchase are far from the final product',
#  'Quality product. Fast delivery. I recommend',
#  'My grade is 10',
#  'Always have this customer service.',
#  'It was what I was expecting very beautiful and its led is perfect without counting the sound which is very powerful at last perfect',
#  'The product is as per the photo. met all my expectations. Super Indico',
#  'The request was not made on 7/7, as stated in this form. Until the product is delivered, I have no way of recommending the store. We have to wait.',
#  'People still haven&#39;t received my order. How do I send you again',
#  'Thank you very much! Loved it arrived before the deadline and perfect! I became a client! Super recommended! Thanks',
#  'The smell really good',
#  'Very easy and fast. Shortest delivery time .. But the product is much less. Thanks.',
#  'Product came right as I saw in the photo and arrived before the deadline. I really liked it!!!',
#  'I love to buy lannister',
#  'Great, perfect product, delivered on time, everything ok.',
#  'Very beautiful, looks like quality. I haven&#39;t applied it yet, so I can&#39;t talk about its adherence. For the cost benefit I recommend.',
#  'VERY GOOD MATERIAL',
#  'It could have come better packed, the watch arrived with some scratches but it is a great product',
#  'I did not note 5 because it did not come in the same packaging. White packaging forbidden for sale, but on the other hand the price was good',
#  'Great',
#  'very good product and arrived perfect',
#  'Fantastic',
#  'When buying 11 dumpsters, I had to pay the freight individually, as if I had bought only 1 dumpster. The stark could have assembled 1 bigger box with the 11 bins inside which would be cheaper',
#  'Ok',
#  'Everything is OK. As per the announcement.',
#  'Perfect',
#  'The products arrived right on time I am very satisfied thank you guys congratulations',
#  'Delivery was ahead of schedule, and the product was delivered as described.',
#  'I recommend the loa because it met the right deadline but the product is very bad ... terrible quality.',
#  'I liked the purchase arrived before the agreed .. I recommend ...',
#  'I recommend fast delivery',
#  'It arrived on time.',
#  'I received the correct source, but the power cable had one of the teeth of the broken socket, other than that I tested the source and it worked perfectly',
#  'product delivered before the deadline, very satisfied.',
#  'I bought the cover, paid for the expensive shipping and when I receive the product the color in which I had purchased it didn&#39;t come. I decided not to return it, due to the additional cost and delay in delivering the correct product.',
#  'Product sent with great care and attention !!! I loved it.',
#  'I received wrong product a week ago. I accepted but the value of the delivered product is less. I asked for a refund but nothing so far, 9 days ago',
#  'I received 2 of the 3 desired products',
#  'Product was not delivered, they only delivered an empty envelope, with nothing, not even a paper inside, an absurd, pure blow, as POLICE.',
#  'Fast delivery before the deadline, very good object according to the announcement.',
#  'I really liked my product, I just think the cloths could be bigger, but everything is alright .... I highly recommend this site, delivery well before the deadline ... I will definitely buy it again.',
#  'Highly quality stores',
#  'Excellent product.',
#  'It arrived very fast, I was in doubt for not knowing the product, but very good the product',
#  'I highly recommend the product and the store!',
#  'Very good product fast delivery',
#  'I expected the price to be better. the material is of low quality and the lid is slightly loose. I didn&#39;t like the absurd price. not worth it.',
#  'SATISFIED WITH PRODUCT, FULFILL THE PURPOSE OF PUMPING WATER, IN MY CASE, FOR A SOURCE OF WATER. AND LANNISER STORES ALWAYS DELIVERY BEFORE TIME AND PRICE BOMMMMM',
#  'I received before the delivery date, the American is to be congratulated, the carpet is very good, beautiful color I highly recommend ...',
#  'I received half the material.',
#  'I haven&#39;t opened the packaging yet because I&#39;m giving it away. But I received it before the deadline.',
#  'Great quality',
#  'Very well attended arrived before the deadline',
#  'The only thing I think q deliveries could be faster every 10 or 15 days and very time consuming',
#  'I was unable to contact the supplier to request the exchange. The clock&#39;s wrong mode came',
#  'Great company, delivered before the deadline. You are to be congratulated.',
#  'I bought a product to deliver to my home, I paid for shipping, and they left it in the mail to pick it up, right, why do they charge shipping then?',
#  'Quality and fair price, with delivery in record time.',
#  'Great quality product and turbo delivery!',
#  'I received it super fast.',
#  'Super fast delivery, I recommend the targaryen partner. NOTE 1000 !!',
#  'Good quality and beautiful material. I just thought it was bigger !!!',
#  'Huge and comfortable product.',
#  'I loved the product and arrived earlier than I expected ... I highly recommend',
#  'good product I really liked it!',
#  'The product was not delivered to my house I had to pick it up at the agency I paid 20 reais for shipping, but I still didn&#39;t receive it at home',
#  'Very good',
#  'Some product items such as glass top and feet, left to leave due to the fragility of the material',
#  'Came with defects',
#  'The fabric was not what I expected, it looks like rubber, just like the plastics we used to cover the tables in school time. I only opened one and the other didn&#39;t even open it, please change this product for me',
#  'I bought it on Monday afternoon. Tuesday was a holiday and on Wednesday the product arrived at my house. Congratulations on your speed.',
#  'The size is small and I realized afterwards that the ad does not highlight the dimensions of the product. Falls short',
#  'The product arrived well before the agreed deadline and safely. I was very satisfied !!!',
#  'Mada to declare',
#  'I still couldn&#39;t test it, but it arrived in Record time.',
#  'Fast delivery and very nice product !!!',
#  'I&#39;m waiting until now I never received any watch I bought not recommended this store',
#  'I HOPE NEVER BUY AND HAVE TO RESPOND TO THIS TYPE OF EVALUATION',
#  'Delivery was made even before the deadline. Well packaged and approved product',
#  'the images showed a different photo of the product I received.',
#  'I bought with the voltage 220 and came 110v',
#  'Perfect delivery and well ahead of schedule.',
#  'I loved the product, I haven&#39;t put it in place yet to test the fixation of the adhesive but I hope it is good. I thought it would be a little bigger, but I am satisfied. Arrived before the deadline👏',
#  'Despite the on-time delivery, the time is long compared to other purchases I usually make via the internet',
#  'Everything is OK',
#  'Poorly made product, crooked, with poorly made welds.',
#  'I bought a product that is defective and I can&#39;t change the error on the website.',
#  'It arrived in perfect condition and ahead of schedule. Thanks for the speed.',
#  'Beautiful pillow, beautiful and big color. I made an excellent purchase.',
#  'Great',
#  'GREAT PARTNERS! CONGRATULATIONS!!!',
#  'The watch arrived without working, and it is not original Oakley.',
#  'quick and practical to buy',
#  'on the website it said it would arrive until 3/13 and it hasn&#39;t arrived yet!',
#  'It does not do what it promises, after it is installed it leaks through the cartridge, even following the instructions, it is not worth it, money thrown away.',
#  'Delivery is delayed and no prediction of when it will arrive',
#  'I paid to deliver it to my residence, I paid for shipping, and I still had to spend it to get it from a post office, completely away from the requested address!',
#  'I DID NOT RECEIVE MY WELDING MACHINE',
#  'Everything is OK',
#  'A super perfect store that buys with its customers what it says to its customer reaches you even before the deadline',
#  'I always bought it and I have no problem, but this is where my products come from so far',
#  'Everything as expected, except for the courier that brought the package looking like it was run over by a train, I had to go through the three products to see if it was lost, as it was leaking.',
#  'Very efficient delivery, with quality product.👍',
#  'All right, thank you.',
#  'I was very satisfied',
#  'Service note 10. Product of great quality and respected delivery time, in fact arrived long before the time given initially! Congratulations.',
#  'Excellent product. I recommend.',
#  'Wonderful product ... recommend',
#  'I recommend',
#  'Very good....',
#  'Expected delivery date 17/5, we are in urgency for this product and nothing.',
#  'The product arrived. However the packaging was open and in one of the arms of the chair the screw fitting was broken. Other than that, the delivery time was good.',
#  'The product is very good',
#  'I haven&#39;t received the goods so far.',
#  'Store delivered earlier than expected',
#  'I love shopping at the store',
#  'the product is good, delivery is fast, but shipping is very expensive.',
#  'On Time and in perfect condition !! Liked it!!!',
#  'RELIABLE STORE, BUT STILL DID NOT RECEIVE THE PRODUCT',
#  'The purchase was made and delivered on time. I recommend the lannister store and website.',
#  'need to receive this product, it must have been delivered to someone else',
#  ...]
